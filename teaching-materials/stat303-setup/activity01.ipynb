# %% [raw]
# ---
# title: "Activity 1: Your First VS Code Notebook"
# author: "Your Name"
# format:
#   html:
#     embed-resources: true
#     toc: true
#     code-fold: false
# ---

# %% [markdown]
# # My First VS Code Notebook
#
# Name: **Your Name**
#
# Open the extracted stat303-setup folder and select a familiar Python kernel. This activity uses only the standard library.

# %%
import sys
from pathlib import Path
print("Python version:", sys.version)
print("Python executable:", sys.executable)
print("Working directory:", Path.cwd())

# %% [markdown]
# ## My Calculation
#
# Add code below to calculate the mean of three readings, then explain your result.

# %%
# Add your calculation here.

# %% [markdown]
# ## My Explanation
#
# Identify your selected Python installation. Explain the difference between a notebook and a kernel. Record whether restart/run all and reopening preserved the expected outputs.
