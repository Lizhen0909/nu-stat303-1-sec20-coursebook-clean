# %% [raw]
# ---
# title: "Jupyter Notebooks in VS Code"
# format:
#   html:
#     css: comparison.css
#     toc: true
#     toc-depth: 3
#     code-fold: false
# jupyter: python3
# ---

# %% [markdown]
# In STAT 201, you used Jupyter notebooks through Anaconda. Throughout STAT303, the Python sequence, you will consistently use **VS Code** to write and run `.ipynb` notebooks. In this sequence, you will also use **Quarto** to produce HTML assignment submissions.
#
# By the end of this chapter, you should be able to:
#
# - Explain the roles of the tools you use.
# - Identify its Python kernel.
# - Open a project folder.
# - Run and save a notebook.
# - Use your existing Quarto installation to render and inspect an HTML submission.

# %% [markdown]
# ## Anaconda vs. VS Code
#
# Anaconda and Visual Studio Code serve different roles and can be used together. Anaconda bundles Python, hundreds of packages, and environment-management tools, making it convenient but requiring more disk space. VS Code is a lightweight code editor that connects to your Python installation and lets you add extensions as needed. The table below compares their purposes and key features.
#
# ::: {.tools-comparison}
#
# | | ![](images/anaconda-icon.svg){.comparison-logo fig-alt=""} **Anaconda** | ![](images/vscode-icon.svg){.comparison-logo fig-alt=""} **Visual Studio Code (VS Code)** |
# |---|---|---|
# | **Overview** | A Python distribution with environment-management tools | A powerful, flexible, and lightweight code editor |
# | **What it is** | A distribution that includes Python, many common packages, and tools such as conda and Navigator | A free code editor from Microsoft, built on the open-source Code - OSS project |
# | **Main purpose** | Makes it easy to install Python and manage packages and environments | Provides a modern, flexible environment to write, run, and debug code in Python and many other languages |
# | **Key features** | • Preinstalls many popular data science packages<br><br>• Environment management with conda<br><br>• Anaconda Navigator graphical interface | • Clean, customizable interface<br><br>• Python support through extensions<br><br>• Integrated terminal and Jupyter notebook support through the Jupyter extension<br><br>• Debugging, code navigation, and Git tools<br><br>• Extensible through additional extensions<br><br>• Works with different Python environments, including Anaconda environments |
#
# :::
#
# **Why we use VS Code throughout STAT303, the Python sequence:**
#
# VS Code provides a consistent workspace across the sequence, so you can build on the same tools and habits as your Python projects grow. The figure below shows how notebooks, code, and the terminal fit together.
#
# ![VS Code brings Python code, Jupyter notebooks, a kernel selector, and an integrated terminal into one workspace. The Python kernel runs in the background and remembers variables between cells.](images/vscode-notebook-tools.png){#fig-vscode-notebook-tools width=100% fig-alt="Illustrated VS Code window with labeled Python code cells, Jupyter notebook editor, kernel selector, and terminal. A separate inset explains that the Python kernel executes cells and stores variables in memory."}
#
# Specifically:
#
# - **Keep the whole project visible.** Open a folder and work with notebooks, Python scripts, data, and report settings together. This helps you see where files belong as an assignment grows.
# - **Continue using familiar notebooks.** Open your existing `.ipynb` files, write Markdown, run cells, and view outputs in the editor.
# - **Get help while coding.** With the Python and Jupyter extensions, code completion, function information, and debugging tools help you explore unfamiliar libraries and investigate errors.
# - **Use a terminal beside your notebook.** Install packages and run Quarto commands without switching to a separate terminal application. You still need to verify its current folder and Python environment.
# - **Build a repeatable submission workflow.** Edit and run your notebook, save it, then use the integrated terminal to render your HTML with Quarto. The same workspace supports each stage of the assignment.

# %% [markdown]
# ## Check Your Existing Setup
#
# **Already have VS Code?** Open it and verify that the **Python** and **Jupyter** extensions from Microsoft are installed and enabled. Then check for Python using the steps below.
#
# **Need VS Code?** Install it from [the official website](https://code.visualstudio.com/), then open the Extensions panel and install Microsoft's Python and Jupyter extensions. On Windows/Linux the shortcut is `Ctrl+Shift+X`; on macOS it is `Cmd+Shift+X`.
#
# ### Find an Existing Python Installation
#
# A **Python interpreter** is the program that runs your Python code. Since you completed STAT 201, you should already have Python installed. Here, you will connect VS Code to that existing installation.
#
# 1. Open VS Code's **Command Palette**: `Ctrl+Shift+P` on Windows/Linux or `Cmd+Shift+P` on macOS.
# 2. Type **Python: Select Interpreter** and select that command.
#
#    ![Find Python in VS Code: open the Command Palette, select Python: Select Interpreter, and identify an existing installation by its version and path. Versions and paths shown are examples.](images/vscode-select-interpreter.png){#fig-select-interpreter width=100% fig-alt="Two-panel illustration of VS Code showing the Python: Select Interpreter command and a picker with an Anaconda environment. Arrows identify the command, Python version, and installation path."}
#
# 3. Look for a listed **Python 3** environment. The entry usually shows a version and an installation path; an Anaconda installation may be labeled **conda** or **base**, or have `anaconda3` or `miniconda3` in its path.
# 4. Select the **Python 3 environment you used in STAT 201**. If you used Anaconda's default environment, choose its **base** environment. An environment includes both a Python version and its installed packages.
#
# - **For this chapter, choose Anaconda's `base` environment.** If you did not use Anaconda, choose the working Python 3 environment you used in STAT 201. In the next chapter, you will learn the disadvantages of using `base` for all Python projects and how to create an isolated, dedicated environment for this course.
# - **Identify it by its executable path.** Open a local Jupyter notebook using your usual STAT 201 setup, run `import sys` followed by `print(sys.executable)`, and match that path to the interpreter in VS Code. Different environments can use the same Python version, so the version number alone is not enough.
# - **Use the same environment for your notebook kernel.** When you open an `.ipynb` file in VS Code, use the kernel picker at the top right to choose that environment as well. Selecting an interpreter and selecting a notebook kernel are separate steps.
# - **If you still cannot identify it, ask for setup assistance.** Share the listed environment names and paths; you do not need to install another copy of Python just because several appear.

# %% [markdown]
# ### Check That It Runs
#
# Finding an interpreter in the list is a first check. Next, verify that it can execute code:
#
# 1. Open the Command Palette again and run **Python: Start Terminal REPL**. This starts an interactive Python session using the selected interpreter.
# 2. When the `>>>` prompt appears, enter these lines **one at a time**, pressing Enter after each. Do not type the `>>>` prompt itself.
#
# ```python
# import sys
# print(sys.version)
# print(sys.executable)
# print(2 + 3)
# ```
#
# You should see a **Python 3 version**, the **path to its executable**, and **`5`**. This confirms that the selected Python installation runs. Keep the executable path so you can identify the same environment later. Type `exit()` and press Enter to leave Python, then continue to **Open a Project Folder** below.

# %% [markdown]
# ### If No Interpreter Appears or Python Does Not Start
#
# An empty list does **not** necessarily mean Python is missing; VS Code may not have found it.
#
# - **No “Python: Select Interpreter” command?** Check that Microsoft's Python extension is installed and enabled, then restart VS Code.
# - **Previously used Anaconda?** Open Anaconda Navigator and try launching a local Jupyter notebook as you did in STAT 201. Run `import sys` followed by `print(sys.executable)` in a code cell. If it works, Python is installed. Copy that path, return to **Python: Select Interpreter**, and use **Enter interpreter path…** if available to locate that executable.
# - **Still cannot find or run Python?** Ask for setup assistance and share the error message. If no working installation is available, install the instructor's supported Python version from the [official Python website](https://www.python.org/downloads/).

# %% [markdown]
# ## Open a Project Folder
#
# [Download the setup practice kit](downloads/setup-practice.zip), extract it, and open the extracted **`stat303-setup` folder** using **File → Open Folder**. Do not work inside the ZIP viewer or open only a notebook without its surrounding folder.
#
# This kit contains the two chapter practice notebooks:
#
# ```text
# stat303-setup/
# ├── activity01.ipynb
# ├── activity02.ipynb
# ├── data/
# │   └── station_readings.csv
# └── README.md
# ```
#
# You will create `.venv/` and `requirements.txt` in Chapter 2. Keep the notebooks alongside `data/` while learning this workflow. This makes the expected working directory explicit; later assignments may use other layouts.
#
# Find these areas in VS Code:
#
# - **Explorer:** project folders and files.
# - **Notebook editor:** code and Markdown cells.
# - **Kernel picker:** usually at the top right of the notebook.
# - **Terminal panel:** open it with **Terminal → New Terminal**; note the shell shown in its tab/menu.
#
# [Assignment B](Assignment%20B.ipynb) has a separate project kit for applying these skills after Chapter 2.

# %% [markdown]
# ## Select a Kernel and Run a Cell
#
# Open `activity01.ipynb`. Use its kernel picker to choose an existing Python environment you recognize from STAT 201. Labels vary with installed extensions; a route such as **Select Another Kernel → Python Environments** may be available. For this first check, your existing environment is sufficient. Chapter 2 establishes a separate course environment.
#
# Run this in a **notebook code cell**, not the terminal:
#
# ```python
# import sys
# print("Notebook is running")
# print(sys.version)
# print(sys.executable)
# ```
#
# The executable path identifies the Python used by this notebook. A kernel name such as `Python 3` is not enough to distinguish multiple installations.
#
# If VS Code reports that `ipykernel` is required, install it for the selected environment using the VS Code prompt. If that environment is managed or read-only, ask for assistance or follow Chapter 2 to create your own environment; do not install into an arbitrary system interpreter.

# %% [markdown]
# ## Code, Markdown, and Saved Outputs
#
# Use code cells for computation and Markdown cells for explanations, headings, and answers. Run cells with their play controls or `Shift+Enter`. Save the notebook with `Ctrl+S` or `Cmd+S`.
#
# A notebook remembers values from previously executed cells. Moving or editing a cell does not undo its earlier effects. Before considering work complete, **restart the kernel, run all code cells in order, and save again**. A successfully executed notebook should not depend on variables created in deleted cells.
#
# The HTML submitted later will be generated from this saved notebook. Writing an explanation in a code comment is useful, but Markdown is better for the report's narrative.

# %% [markdown]
# ## If Something Does Not Work While Working in a Notebook
#
# Already have Python running (see **Check Your Existing Setup** above) but still stuck? Check these notebook-specific symptoms:
#
# | Symptom | First check |
# |---|---|
# | No kernel is offered | Python/Jupyter extensions are enabled; a Python interpreter is installed and discoverable |
# | Code will not run | The cell is Code rather than Markdown and a kernel is selected |
# | Output differs after restarting | All required assignments/imports occur earlier in the notebook |
# | You cannot find the data folder | The ZIP is extracted and the correct project folder is open |

# %% [markdown]
# ## Render and Submit with Quarto
#
# In STAT201, you already used Quarto to generate HTML from notebooks in your Anaconda-based workflow. The same Quarto application works with notebooks edited in VS Code. This is a refresher on completing that workflow in the new editor.
#
# ### Check Your Existing Quarto Installation
#
# Open **Terminal → New Terminal** in VS Code and enter:
#
# ```text
# quarto --version
# ```
#
# A version number means this terminal can find Quarto. You do not need to reinstall it simply because you changed editors. If the command is not found, restart VS Code and check your existing Quarto installation. If it is missing, install the **Quarto application** from the [official download page](https://quarto.org/docs/get-started/) and open a new terminal.
#
# The **Quarto VS Code extension is optional** for our workflow. It adds editing assistance and integrated previews; it is not required to run `quarto render` in the terminal. The Quarto application, the Python/Jupyter extensions used for notebooks, and the optional Quarto extension serve different purposes. See [Quarto's VS Code guide](https://quarto.org/docs/tools/vscode/index.html).
#
# ### Keep the Template's Report Settings
#
# The practice notebooks start with a **Raw** cell containing settings like these:
#
# ```yaml
# ---
# title: "Activity 1: Your First VS Code Notebook"
# author: "Your Name"
# format:
#   html:
#     embed-resources: true
#     toc: true
#     code-fold: false
# ---
# ```
#
# Edit the existing title and author when appropriate; retain the indentation and `---` lines. This is YAML configuration, not Python code. Keep it in the supplied Raw cell. `toc: true` adds a table of contents, and `code-fold: false` keeps code visible for grading.
#
# `embed-resources: true` puts ordinary figures and styling inside the HTML. It does not include your Python environment or input data for rerunning the work, and external websites or services can still require internet access.
#
# ### Restart, Run All, Save, Render, Inspect
#
# Quarto normally renders an `.ipynb` file using its **saved outputs**. It does not rerun notebook code by default. A successful render alone does not show that your current code runs correctly. Follow this sequence:
#
# 1. Select the intended notebook kernel. For Chapter 1, use your familiar working STAT201 environment; Chapter 2 introduces a project environment.
# 2. Restart the kernel and run every code cell from top to bottom. Resolve unexpected errors. Use Markdown headings and explanations near the results they discuss.
# 3. Save the notebook. Keep necessary imports and computations, and remove irrelevant exploratory output.
# 4. In the terminal, check that you are in the folder containing the notebook. List its files with `ls` on macOS, `Get-ChildItem` in Windows PowerShell, or `dir` in Windows Command Prompt. If needed, use `cd` with the actual folder path in quotes; Chapter 2 explains navigation in detail.
# 5. Run `quarto render filename.ipynb --to html`, replacing `filename.ipynb` with your notebook's name. Quote a filename containing spaces, for example `quarto render "my assignment.ipynb" --to html`.
# 6. Open the resulting HTML in a browser. Check your name or required identifier, explanations, code, and current outputs. Copy **only the HTML** to another folder and open the copy to check that ordinary figures and formatting travel with it. Correct the notebook and repeat saving/rendering if anything is missing.
#
# The standalone practice kits have no Quarto project configuration redirecting output, so the HTML is created beside the notebook. Keep the notebook and data for future work; upload the HTML requested in the activity or assignment. Detailed notebook rendering behavior is described in [Quarto's notebook guide](https://quarto.org/docs/tools/jupyter-lab.html).
#
# ::: {.callout-note collapse="true" title="Troubleshooting rendering and saved output"}
#
# | Symptom | First check |
# |---|---|
# | Quarto command not found | Existing Quarto application installation and a fresh VS Code terminal |
# | No valid input files | Terminal folder and the notebook's exact filename |
# | Missing or old outputs in HTML | Restart/run all, save, render again, and open the newly generated HTML |
# | Raw YAML appears in the report | Keep the settings in the supplied Raw cell rather than a Markdown or code cell |
# | Figure or styling missing from the copied HTML | Confirm `embed-resources: true` in the Raw cell and render again |
# | Notebook import or file error | Resolve it before rendering; Chapter 2 covers environment and file-path checks |
#
# :::

# %% [markdown]
# ## Practice Activity: Your First VS Code Notebook
#
# **Goal:** Demonstrate that you can use a familiar notebook in the new editor. **File:** `activity01.ipynb` from the practice kit. **Submit:** `activity01.html` through the final file-upload question in the Chapter 1 Canvas quiz. No data science package installation is required for this activity.
#
# Follow this section for the complete activity instructions, then answer the multiple-choice questions and upload your HTML in Canvas.
#
# 1. Open the extracted project folder and select your intended kernel.
# 2. Replace the notebook's name placeholder with your name in Markdown.
# 3. Run the supplied environment-information cell. Add a Markdown sentence identifying which Python installation you selected.
# 4. Add a code cell that defines three numerical readings in a list and prints their mean using `sum()` and `len()`.
# 5. Add a Markdown explanation of what the code does. Explain the difference between a notebook and its kernel.
# 6. Restart the kernel, run all cells, save, close the notebook, and reopen it. In Markdown, record whether the fresh run and reopening preserved the expected outputs, then save again.
#
# **Completion checks:** Your name and explanation render as text, the calculation produces a visible result, and the outputs remain present after reopening. You can point to Explorer, the kernel picker, and the terminal without confusing their roles.
#
# ### Render and Submit Your HTML
#
# Follow the [Quarto refresher](#render-and-submit-with-quarto) above. From `stat303-setup`, render your saved notebook with:
#
# ```text
# quarto render activity01.ipynb --to html
# ```
#
# Inspect `activity01.html`, including a copy opened outside the project folder. Check that your name, Python information, mean calculation and result, explanations, and completion note appear. Upload this HTML to the final question in the **Chapter 1 Canvas quiz**. If you correct the notebook, save and render again before uploading.
#
# **HTML grading (16 points):** name and readable Markdown (2), Python identification (4), mean calculation (4), explanation of code and kernel (4), and completion checks and readable HTML (2). Use your own three numerical readings; the example below is not required.
#
# **Keep:** your saved `activity01.ipynb` and the practice-kit files for later chapters. Submit only the HTML file to this quiz.
#
# ::: {.callout-note collapse="true" title="Self-check"}
# For readings `[18, 20, 22]`, the mean is `20.0`. The notebook is the document; the kernel is the process running its code. Existing outputs can remain visible even when the kernel has stopped, so visible output alone does not establish that a fresh run works.
# :::
#
# Continue to [Project Environments, Packages, and File Paths](python_venv.ipynb).
#
# References: [VS Code notebooks](https://code.visualstudio.com/docs/datascience/jupyter-notebooks), [Python environments](https://code.visualstudio.com/docs/python/environments).
