# %% [raw]
# ---
# title: "Activity 8: Choose, Draw, and Defend a Plot"
# author: "Your Name"
# format:
#   html:
#     theme: cosmo
#     embed-resources: true
#     code-fold: false
# jupyter: python3
# ---

# %% [markdown]
# Follow the [complete chapter instructions](https://lizhen0909.github.io/nu-stat303-1-sec20-coursebook-clean/data_viz_1.html#practice-activity-choose-draw-and-defend-a-plot).
# Add your plots, outputs, and explanations below.
#
# Run the setup cell first. It imports the three libraries and loads the Palmer penguins
# dataset that comes with seaborn, so this activity needs no data file. The first call
# downloads the data and caches it, so the first run needs a network connection.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = sns.load_dataset("penguins")

print("shape:", df.shape)
print("columns:", list(df.columns))
df.head()

# %% [markdown]
# ## A. One Numeric Variable, and What the Bins Decide
#
# Write your three shape descriptions, the bin count you would report and why, the number
# of penguins the histogram left out, and what each of the three views hides.

# %%
# Add your work here.

# %% [markdown]
# ## B. One Categorical Variable, in Two Libraries
#
# Write your comparison of the pandas and seaborn versions here.

# %%
# Add your work here.

# %% [markdown]
# ## C. Two Numeric Variables, and a Line Only Where It Belongs
#
# Interpret the correlation, say what happens inside each species, explain what the pooled
# line claims and why it is wrong here, and finish with your sentence about correlations
# computed over a mixed population.

# %%
# Add your work here.

# %% [markdown]
# ## D. Groups, Hidden Aggregation, and a Finished Plot
#
# Name what seaborn computed for you, what the vertical line on each bar represents, which
# plot you would report, and why a bar chart of means has to start at zero. Confirm that
# your saved PNG is not blank.

# %%
# Add your work here.

# %% [markdown]
# ## Completion Note
#
# Replace this text with a short note confirming you restarted the kernel, ran all cells in
# order, and checked the rendered HTML.
