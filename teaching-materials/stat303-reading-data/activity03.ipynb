# %% [raw]
# ---
# title: "Activity 3: Read, Inspect, and Export Movie Data"
# author: "Your Name"
# format:
#   html:
#     embed-resources: true
#     toc: true
#     code-fold: false
# ---

# %% [markdown]
# # Reading Data Activity
#
# Name: **Your Name**
#
# Follow the [complete chapter instructions](https://lizhen0909.github.io/nu-stat303-1-sec20-coursebook-clean/Reading_data.html#practice-activity-read-inspect-and-export-movie-data). Use the verified Chapter 2 project environment. The working directory should be `stat303-reading-data`.

# %%
from pathlib import Path
import pandas as pd
print("Working directory:", Path.cwd())
print("CSV found:", Path("data/movie_ratings.csv").is_file())
print("Text found:", Path("data/movie_ratings_semicolon.txt").is_file())

# %% [markdown]
# ## A. Read and Orient Yourself
#
# Record the import, requested outputs, and interpretation for A.

# %%
# Add your CSV import and inspection code here.

# %% [markdown]
# Write your explanation here.

# %% [markdown]
# ## B. Inspect and Explain
#
# Record the inspection results, rating summary, Series comparison, and attribute/method explanation for B.

# %%
# Add your inspection and Series code here.

# %% [markdown]
# Write your explanation here.

# %% [markdown]
# ## C. Diagnose a Delimiter
#
# Preview the text, then record your prediction before running the default-import diagnostic.

# %%
text_path = Path("data/movie_ratings_semicolon.txt")
print("\n".join(text_path.read_text(encoding="utf-8").splitlines()[:2]))

# %% [markdown]
# Write your explanation here.

# %%
try:
    default_import = pd.read_csv(text_path)
    print("Default-import shape:", default_import.shape)
    print("Default-import columns:", default_import.columns.tolist())
    display(default_import.head())
except pd.errors.ParserError as error:
    print("Default-import parsing error:", error)

# %%
# Add the corrected import and comparison here.

# %% [markdown]
# Explain your diagnostic evidence and corrected import here.

# %% [markdown]
# ## D. Export and Check
#
# Record the export, reimport checks, and index explanations for D.

# %%
# Add your export and reimport code here.

# %% [markdown]
# Write your explanation here.

# %% [markdown]
# ## Completion Note
#
# Record your fresh-run, save, and HTML inspection checks.
