# %% [raw]
# ---
# title: "Activity 1: My First VS Code Notebook"
# author: "Your Name"
# format:
#   html:
#     embed-resources: true
#     toc: true
#     code-fold: false
# ---

# %% [markdown]
# ## Setup
#
# Before running any cells:
#
# 1. Put your name in the `author` field of the YAML header above.
# 2. Select a familiar Python kernel (top-right of the notebook toolbar). This activity only uses the standard library, so any Python 3 kernel will work.

# %%
import sys
from pathlib import Path
print("Python version:", sys.version)
print("Python executable:", sys.executable)
print("Working directory:", Path.cwd())
# Out:
# Python version: 3.14.7 (main, Aug  5 2026, 10:29:49) [Clang 21.0.0 (clang-2100.1.1.101)]
# Python executable: /Users/lizhenshi/mydev/nu-stat303-1-sec20-coursebook-clean/teaching-materials/stat303-setup/.venv/bin/python
# Working directory: /Users/lizhenshi/mydev/nu-stat303-1-sec20-coursebook-clean/teaching-materials/stat303-setup

# %% [markdown]
# ## My Calculation
#
# Add code below to calculate the mean of three readings, then explain your result.

# %%
# Add your calculation here.

# %% [markdown]
# ## My Explanation
#
# Identify your selected Python installation. Explain the difference between a notebook and a kernel. Record whether restart/run all and reopening preserved the expected outputs.
