# %% [raw]
# ---
# title: "Activity 9: Build and Defend a Multi-Panel Figure"
# author: "Your Name"
# format:
#   html:
#     theme: cosmo
#     embed-resources: true
#     code-fold: false
# jupyter: python3
# ---

# %% [markdown]
# Follow the [complete chapter instructions](https://lizhen0909.github.io/stat303-1-sec20-coursebook/data_viz_2.html#practice-activity-build-and-defend-a-multi-panel-figure).
# Add your figures, outputs, and explanations below.
#
# Run the setup cell first. It imports the three libraries and loads the Palmer penguins
# dataset that comes with seaborn, so this activity needs no data file. The first call
# downloads the data and caches it, so the first run needs a network connection.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = sns.load_dataset("penguins")
numeric_cols = ["bill_length_mm", "bill_depth_mm", "flipper_length_mm", "body_mass_g"]

print("shape:", df.shape)
print("numeric columns:", numeric_cols)
df.head()

# %% [markdown]
# ## A. The Two Interfaces, and a Title That Goes Astray
#
# Say what `fig` and `ax` refer to, report where the stray `plt.title()` landed and why,
# and show the fix.

# %%
# Add your work here.

# %% [markdown]
# ## B. A Grid Whose Panels Are Comparable
#
# Write down your predicted index and `axes.shape` before you run anything, then explain
# why sharing the y-axis matters for this comparison.

# %%
# Add your work here.

# %% [markdown]
# ## C. Looping Over Panels, and One Figure-Wide Label
#
# Say what the self-comparison panel showed, what you replaced it with, and confirm your
# saved PNG is complete.

# %%
# Add your work here.

# %% [markdown]
# ## D. Axes-Level or Figure-Level
#
# Compare the two ways of building the faceted figure, explain the `ax=` failure, and say
# what the per-species regression lines show that a pooled line hid.

# %%
# Add your work here.

# %% [markdown]
# ## Completion Note
#
# Replace this text with a short note confirming you restarted the kernel, ran all cells in
# order, and checked the rendered HTML.
