# %% [raw]
# ---
# title: "Assignment B: Setting Up a Reproducible Python Project"
# author: "Your Name"
# format:
#   html:
#     embed-resources: true
#     toc: true
#     code-fold: false
# ---

# %% [markdown]
# # Assignment B Work Notebook
#
# Name: **Your Name**
#
# Complete the numbered questions on the [Assignment B page](https://lizhen0909.github.io/nu-stat303-1-sec20-coursebook-clean/Assignment%20B.html). That page is the authoritative source of instructions, point allocations, and submission requirements. This starter contains answer spaces and the supplied analysis code. Record terminal evidence in Markdown, not in Python code cells.

# %% [markdown]
# ## 1. Project and Tools
#
# Answer 1.1 and 1.2 here.
#
# *Your answer:*

# %% [markdown]
# ## 2. Environment
#
# Answer 2.1–2.3 here. Complete package setup in Question 3 before running the notebook checks.
#
# *Your answer:*

# %%
# Display Python version, executable, and notebook working directory.

# %% [markdown]
# ## 3. Packages
#
# Answer 3.1–3.3 here. Record installation commands in Markdown; keep installation cells out of the final fresh run.
#
# *Your answer:*

# %%
# Import the four data science packages and display their versions.

# %% [markdown]
# ## 4. Navigation and Paths
#
# Answer 4.1–4.3 here. Keep terminal and notebook observations clearly labeled.
#
# *Your answer:*

# %%
# Construct and verify the data path using pathlib.

# %% [markdown]
# ## 5. Dependencies and Diagnosis
#
# Answer 5.1 and 5.2 here.
#
# *Your answer:*

# %%
# Predict and check an incorrect path, then verify the original correct path.

# %% [markdown]
# ## 6. Supplied Analysis and Interpretation
#
# Run the supplied cells after verifying your environment and data path. Answer 6.1 and 6.2 in the Markdown cell below the plot.

# %%
from pathlib import Path
import pandas as pd

data = pd.read_csv(Path("data") / "library_visits.csv")
display(data)
print("Number of records:", len(data))
print("Mean visits:", data["visits"].mean())

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.bar(data["branch_id"], data["visits"])
ax.set_title("Illustrative Library Visits for One Day")
ax.set_xlabel("Branch ID")
ax.set_ylabel("Number of visits")
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Answers to 6.1 and 6.2
#
# *Your interpretation:*

# %% [markdown]
# ## 7. HTML Submission Checks
#
# Record the verification statement requested in Question 7 here.
#
# *Your verification:*
